# %% [markdown]
# <a href="https://colab.research.google.com/github/DISHANTJOSHI1/dishant_data690/blob/main/assignment_05/assignment_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('MERGED2017_18_PP.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (1729) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# #Look at the first 5 colleges

# %%
df.head(5)
# df.INSTNM.head(5)
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
# 3     AL       35899           NaN      NaN     NaN  ...
# 4     AL  36104-0271           NaN      NaN     NaN  ...
#
#    OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN   G12MN  \
# 0                           NaN       0.7106        0.7418   5207.0  1185.0
# ...

# %% [markdown]
# #look at the last 5 colleges

# %%
df.tail(5)
# Out:
#         UNITID    OPEID  OPEID6  \
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM             CITY  \
# 7107                   Arizona State University at Yuma             Yuma
# 7108  Bay Area Medical Academy - San Jose Satellite ...         San Jose
# 7109           High Desert Medical College - Bakerfield      Bakersfield
# 7110                                       BCI - Malden           Malden
# 7111               HCI College - Fort Lauderdale Campus  Fort Lauderdale
#
#      STABBR        ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 7107     AZ  853656900           NaN      NaN     NaN  ...
# 7108     CA      95113           NaN      NaN     NaN  ...
# 7109     CA      93301           NaN      NaN     NaN  ...
# 7110     MA  021480000           NaN      NaN     NaN  ...
# ...

# %% [markdown]
# #how many colleges or rows?

# %%
uni_college = df.INSTNM.nunique() # Number of unique colleges
print('Number of unique colleges', uni_college)
# Out:
# Number of unique colleges 6974

# %%
df.shape
# Out:
# (7112, 1986)

# %%
count_row = df.shape[0]
print('Number of rows are', count_row)
# Out:
# Number of rows are 7112

# %% [markdown]
# #how many variables or columns?

# %%
count_col = df.shape[1]  # Gives number of columns
print('Number of columns are', count_col)
# Out:
# Number of columns are 1986

# %% [markdown]
# #Look at a random sample of 5 colleges

# %%
df.sample(5)
# Out:
#       UNITID    OPEID  OPEID6  \
# 2317  192785   276300    2763
# 2099  184968   641700    6417
# 6451  487083  4184701   41847
# 3040  213491  2292700   22927
# 2669  202152  2272700   22727
#
#                                                  INSTNM              CITY  \
# 2317                            Maria College of Albany            Albany
# 2099  Holy Name Medical Center-Sister Claire Tynan S...  Englewood Cliffs
# 6451                                    Protege Academy      Mt. Pleasant
# 3040                 Lansdale School of Cosmetology Inc          Lansdale
# 2669      Columbiana County Career and Technical Center            Lisbon
#
#      STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 2317     NY       12208           NaN      NaN     NaN  ...
# 2099     NJ       07632           NaN      NaN     NaN  ...
# 6451     MI  48858-2058           NaN      NaN     NaN  ...
# 3040     PA  19446-2003           NaN      NaN     NaN  ...
# ...

# %% [markdown]
# #New dataframe with important variables only

# %%
new_df = df[['UNITID','INSTNM','CITY','STABBR','ZIP','ADM_RATE','UGDS','TUITIONFEE_IN','MN_EARN_WNE_P10']]

# %% [markdown]
# #Look at the first 10 colleges

# %%
new_df.head(10)
# Out:
#    UNITID                               INSTNM            CITY STABBR  \
# 0  100654             Alabama A & M University          Normal     AL
# 1  100663  University of Alabama at Birmingham      Birmingham     AL
# 2  100690                   Amridge University      Montgomery     AL
# 3  100706  University of Alabama in Huntsville      Huntsville     AL
# 4  100724             Alabama State University      Montgomery     AL
# 5  100751            The University of Alabama      Tuscaloosa     AL
# 6  100760    Central Alabama Community College  Alexander City     AL
# 7  100812              Athens State University          Athens     AL
# 8  100830      Auburn University at Montgomery      Montgomery     AL
# 9  100858                    Auburn University          Auburn     AL
#
#           ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0       35762    0.9027   4824.0         9857.0              NaN
# 1  35294-0110    0.9181  12866.0         8328.0              NaN
# ...

# %% [markdown]
# #look at the last 10 colleges

# %%
new_df.tail(10)
# Out:
#         UNITID                                             INSTNM  \
# 7102  48154401  National Personal Training Institute of Cleveland
# 7103  48305401             Barber School of Pittsburgh - Ambridge
# 7104  48312401                 Arizona State University at Tucson
# 7105  48312402  Arizona State University - ASU Colleges at Lak...
# 7106  48312403        Arizona State University at The Gila Valley
# 7107  48312404                   Arizona State University at Yuma
# 7108  48387801  Bay Area Medical Academy - San Jose Satellite ...
# 7109  48400201           High Desert Medical College - Bakerfield
# 7110  48778201                                       BCI - Malden
# 7111  49005401               HCI College - Fort Lauderdale Campus
#
#                   CITY STABBR        ZIP  ADM_RATE  UGDS  TUITIONFEE_IN  \
# 7102  Highland Heights     OH      44143       NaN   NaN            NaN
# 7103          Ambridge     PA  150030000       NaN   NaN            NaN
# ...

# %% [markdown]
# #Look at a random sample of 10 colleges

# %%
new_df.sample(10)
# Out:
#       UNITID                                             INSTNM  \
# 3106  215053             Pennsylvania College of Art and Design
# 4731  433013                          Career Networks Institute
# 2517  198729                     James Sprunt Community College
# 3317  220118  Chattanooga College Medical Dental and Technic...
# 6166  481678                       Empire Beauty School-Augusta
# 6637  490601  Kansas City University of Medicine and Bioscie...
# 1308  156754                PJ's College of Cosmetology-Glasgow
# 5640  457925                       Portland Actors Conservatory
# 721   135337                             Loraines Academy & Spa
# 3261  218919                                   Voorhees College
#
#                   CITY STABBR         ZIP  ADM_RATE    UGDS  TUITIONFEE_IN  \
# 3106         Lancaster     PA  17608-0059    0.5000   257.0        25000.0
# 4731         Santa Ana     CA       92705       NaN   403.0            NaN
# ...

# %% [markdown]
# #Find and display UMBC

# %%
new_df[new_df.INSTNM=='Johns Hopskins']
# Out:
# Empty DataFrame
# Columns: [UNITID, INSTNM, CITY, STABBR, ZIP, ADM_RATE, UGDS, TUITIONFEE_IN, MN_EARN_WNE_P10]
# Index: []

# %% [markdown]
# #Filter the smaller dataset further to only keep colleges from Maryland, Virgina, Washington DC, Delaware, and Pennsylvinia. Save the filtered dataset to a new file named "Five_States_Colleges.csv" for future analysis.

# %%
five_state = new_df[(new_df.STABBR == 'MD') | (new_df.STABBR == 'VA') | (new_df.STABBR == 'WA')|(new_df.STABBR == 'DE')|(new_df.STABBR == 'PA')]

# %%
five_state.shape
# Out:
# (785, 9)

# %%
five_state.to_csv('Five_States_Colleges.csv',index=False) # converting five_state dataframe to csv file
